# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Varun M__
# <br>
# Current Occupation : Content Analyst
# <br>
# Desired Occupation : Data Analyst/Financial Analyst

# %% [markdown]
# _I am interested in data science because, working in data centric company made me realize how important data can be to make decisions and analyze things._

# %% [markdown]
# ### The below code will take some variable and print it

# %%
name = "Varun"
favorite_language = "Python"

print(f"Hi, I'm {name}. I'm learning {favorite_language} with help of IBM Watson Studios.")
# Out:
# Hi, I'm Varun. I'm learning Python with help of IBM Watson Studios.

# %% [markdown]
# 1. First Item
# 2. Second Item
# 3. Third Item
# 4. Fourth Item
#
# ___
#
# - One
# - Two
# - Three
# - Four
